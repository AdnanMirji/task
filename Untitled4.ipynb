# %% [markdown]
# <a href="https://colab.research.google.com/github/AdnanMirji/task/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

data = pd.read_csv('/content/drive/MyDrive/Task_1/Book1.csv')


features = data.iloc[:, 0:3].values


target = data.iloc[:, -1].values


MLR = LinearRegression()


MLR.fit(features, target)


predictions = MLR.predict(features)


mse = mean_squared_error(target, predictions)

plt.scatter(target, predictions)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()

print("MSE:", mse)
print("Intercepts:", MLR.intercept_)
print("Coefficients:", MLR.coef_)
# Out:
# MSE: 8.170345089789052e-31
# Intercepts: -2.6645352591003757e-15
# Coefficients: [-1.21883697e-17  1.00000000e+00]
