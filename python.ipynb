# %% [markdown]
# # **my first program**

# %%
print("iam Adnan")
# Out:
# iam Adnan

# %%
a+b

# %% [markdown]
# variable declaration

# %%
a=10
b=12
sum=a+b
print(sum)
print("sum")
# Out:
# 22
# sum

# %% [markdown]
# assignment

# %%
a=10
b=5
sub=a-b
print(sub)
# Out:
# 5

# %% [markdown]
# multiplication

# %%
a=20
b=30
mul=a*b
print(mul)
# Out:
# 600

# %% [markdown]
# division

# %%
a=20
b=30
div=a/b
print(div)
# Out:
# 0.6666666666666666

# %% [markdown]
# square

# %%
a=25
squ=a*a
print(squ)
# Out:
# 625

# %% [markdown]
# square root

# %%
a=9
root=a**1/2
print(root)
# Out:
# 4.5

# %% [markdown]
# power

# %%
a=9
b=2
power=a**b
print(power)
# Out:
# 81

# %% [markdown]
# data types

# %%
name="adnan"
print(type(name))
# Out:
# <class 'str'>

# %%
name2="adnan & 123"
print(type(name2))
# Out:
# <class 'str'>

# %%
num1=45
num2=4j
num3=-99
num4=22.22
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'complex'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# sequence data type
# list
# tuples
# range
#
# list
# ordered
# mutable
# allow dupliicates

# %%
lis=["adnan,shahed,gouse"]
print(type(lis))
# Out:
# <class 'list'>

# %%
lis1=["apple,catt,dog"]
lis2=["adnan,shahed,gouse"]
lis3=lis1+lis2
print(len(lis1))
print(len(lis2))
print(lis3)
# Out:
# 1
# 1
# ['apple,catt,dog', 'adnan,shahed,gouse']

# %%
lis=["aaa","nnn","bbbb"]
lis.append("ccc")
print(lis)
lis.sort()
print(lis)
lis.clear()
# Out:
# ['aaa', 'nnn', 'bbbb', 'ccc']
# ['aaa', 'bbbb', 'ccc', 'nnn']

# %%
import random

gamelist=['stone','paper','scissor']
comp=random.choice(gamelist)
user=input("Enter  ")
print(comp,user)
# Out:
# Enter  stone
# stone stone

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,1,10)
m=0.6
c=25
y=m*x+c
plt.plot(x,y)
plt.grid()
plt.show()

# %%
import pandas as pd
data=pd.read_csv('/content/sample_data/california_housing_test.csv')
print(data)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
import pandas as pd
data=pd.read_excel('/content/Activity_1_Data.xlsx')
print(data)
# Out:
#      1.000000  1.722778  2.081019
# 0           2  1.853528  2.605910
# 1           3  2.590116  1.920842
# 2           4  2.188698  2.146486
# 3           5  2.495787  3.233857
# 4           6  2.301726  2.573117
# ..        ...       ...       ...
# 164       166 -2.910219  2.990541
# 165       167 -3.509659  3.081623
# 166       168 -2.981200  2.639425
# 167       169 -2.931438  3.205302
# 168       170 -3.760526  2.393684
#
# [169 rows x 3 columns]
